# %%
# Source - https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
# Posted by Gaurav Singh
# Retrieved 11/5/2025, License - CC-BY-SA 4.0

import pandas as pd


df = pd.read_csv('X_Tweets_Aggregated.csv')

df = df[(df['Timestamp'] > '2024-05-10') & (df['Timestamp'] < '2025-05-10')]

df.to_csv("X_Tweets_Filtered.csv", index=False)

df.describe()
# Out:
#                 Name       Handle                 Timestamp Verified  \
# count           1186         1189                      1189     1189
# unique           226          229                      1189        2
# top     ABS-CBN News  @ABSCBNNews  2025-04-12T03:46:11.000Z     True
# freq             262          262                         1      642
#
#                                                   Content Comments Retweets  \
# count                                                1189     1189     1189
# unique                                               1181      158      291
# top     The Panagbenga “politicians” will now be banne...        0        6
# freq                                                    2      208       52
#
#        Likes Analytics              Tags Mentions Emojis  \
# count   1189      1189              1189     1189   1189
# unique   439       387               252      126    180
# top       24       10K  ['#Halalan2025']       []     []
# freq      19        28               682      901    935
#
#                                             Profile Image  \
# count                                                1189
# unique                                                255
# top     https://pbs.twimg.com/profile_images/141490472...
# freq                                                  204
#
#                                                Tweet Link  \
# count                                                1189
# unique                                               1189
# top     https://x.com/PHLinLosAngeles/status/191090224...
# freq                                                    1
#
#                             Tweet ID
# count                           1189
# unique                          1189
# top     tweet_id:1910902241202184588
# freq                               1
